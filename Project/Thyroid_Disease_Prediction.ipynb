# %% [markdown]
# #### Importing libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
import pickle

# %% [markdown]
# #### Reading Data

# %%
data=pd.read_csv('C:/Users/User/Documents/Medical_Diagnosis_System/project/Datasets/hypothyroid.csv',na_values=["?"])

# %%
data.head()
# Out:
#     age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0  41.0   F            f                  f                         f    f
# 1  23.0   F            f                  f                         f    f
# 2  46.0   M            f                  f                         f    f
# 3  70.0   F            t                  f                         f    f
# 4  70.0   F            f                  f                         f    f
#
#    ... FTI measured    FTI TBG measured TBG referral source binaryClass
# 0  ...            t  109.0            f NaN            SVHC           P
# 1  ...            f    NaN            f NaN           other           P
# 2  ...            t  120.0            f NaN           other           P
# 3  ...            f    NaN            f NaN           other           P
# 4  ...            t   70.0            f NaN             SVI           P
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Data Analysis

# %%
data.shape
# Out:
# (3772, 30)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3772 entries, 0 to 3771
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        3771 non-null   float64
#  1   sex                        3622 non-null   object
#  2   on thyroxine               3772 non-null   object
#  3   query on thyroxine         3772 non-null   object
#  4   on antithyroid medication  3772 non-null   object
#  5   sick                       3772 non-null   object
#  6   pregnant                   3772 non-null   object
#  7   thyroid surgery            3772 non-null   object
#  8   I131 treatment             3772 non-null   object
#  9   query hypothyroid          3772 non-null   object
#  10  query hyperthyroid         3772 non-null   object
#  11  lithium                    3772 non-null   object
#  12  goitre                     3772 non-null   object
#  13  tumor                      3772 non-null   object
#  14  hypopituitary              3772 non-null   object
#  15  psych                      3772 non-null   object
#  16  TSH measured               3772 non-null   object
#  17  TSH                        3403 non-null   float64
#  18  T3 measured                3772 non-null   object
#  19  T3                         3003 non-null   float64
#  20  TT4 measured               3772 non-null   object
#  21  TT4                        3541 non-null   float64
#  22  T4U measured               3772 non-null   object
#  23  T4U                        3385 non-null   float64
#  24  FTI measured               3772 non-null   object
#  25  FTI                        3387 non-null   float64
#  26  TBG measured               3772 non-null   object
#  27  TBG                        0 non-null      float64
#  28  referral source            3772 non-null   object
#  29  binaryClass                3772 non-null   object
# dtypes: float64(7), object(23)
# memory usage: 884.2+ KB

# %%
data.describe()
# Out:
#                age          TSH           T3          TT4          T4U  \
# count  3771.000000  3403.000000  3003.000000  3541.000000  3385.000000
# mean     51.735879     5.086766     2.013500   108.319345     0.995000
# std      20.084958    24.521470     0.827434    35.604248     0.195457
# min       1.000000     0.005000     0.050000     2.000000     0.250000
# 25%      36.000000     0.500000     1.600000    88.000000     0.880000
# 50%      54.000000     1.400000     2.000000   103.000000     0.980000
# 75%      67.000000     2.700000     2.400000   124.000000     1.080000
# max     455.000000   530.000000    10.600000   430.000000     2.320000
#
#                FTI  TBG
# count  3387.000000  0.0
# mean    110.469649  NaN
# std      33.089698  NaN
# min       2.000000  NaN
# 25%      93.000000  NaN
# 50%     107.000000  NaN
# 75%     124.000000  NaN
# max     395.000000  NaN

# %%
data["binaryClass"].value_counts()
# Out:
# binaryClass
# P    3481
# N     291
# Name: count, dtype: int64

# %%
# dropping columns that have most missing values
data=data.drop(columns="TBG",axis=1)
data
# Out:
#        age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0     41.0   F            f                  f                         f    f
# 1     23.0   F            f                  f                         f    f
# 2     46.0   M            f                  f                         f    f
# 3     70.0   F            t                  f                         f    f
# 4     70.0   F            f                  f                         f    f
# ...    ...  ..          ...                ...                       ...  ...
# 3767  30.0   F            f                  f                         f    f
# 3768  68.0   F            f                  f                         f    f
# 3769  74.0   F            f                  f                         f    f
# 3770  72.0   M            f                  f                         f    f
# 3771  64.0   F            f                  f                         f    f
#
#       ...   T4U FTI measured    FTI TBG measured referral source binaryClass
# 0     ...  1.14            t  109.0            f            SVHC           P
# 1     ...   NaN            f    NaN            f           other           P
# 2     ...  0.91            t  120.0            f           other           P
# 3     ...   NaN            f    NaN            f           other           P
# 4     ...  0.87            t   70.0            f             SVI           P
# ...   ...   ...          ...    ...          ...             ...         ...
# 3767  ...   NaN            f    NaN            f           other           P
# 3768  ...  1.08            t  114.0            f             SVI           P
# 3769  ...  1.07            t  105.0            f           other           P
# 3770  ...  0.94            t   87.0            f             SVI           P
# 3771  ...  1.07            t   92.0            f           other           P
#
# [3772 rows x 29 columns]

# %%
# checking null values
data.isnull().sum()
# Out:
# age                            1
# sex                          150
# on thyroxine                   0
# query on thyroxine             0
# on antithyroid medication      0
# sick                           0
# pregnant                       0
# thyroid surgery                0
# I131 treatment                 0
# query hypothyroid              0
# query hyperthyroid             0
# lithium                        0
# goitre                         0
# tumor                          0
# hypopituitary                  0
# psych                          0
# TSH measured                   0
# TSH                          369
# T3 measured                    0
# T3                           769
# TT4 measured                   0
# TT4                          231
# T4U measured                   0
# T4U                          387
# FTI measured                   0
# FTI                          385
# TBG measured                   0
# referral source                0
# binaryClass                    0
# dtype: int64

# %% [markdown]
# #### Data Preprocessing

# %%
# converting objects to numericals
data["binaryClass"]=data["binaryClass"].map({"P":0,"N":1})
data=data.replace({"t":1,"f":0,"M":0,"F":1})
data
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5712\3995993780.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data=data.replace({"t":1,"f":0,"M":0,"F":1})
#        age  sex  on thyroxine  query on thyroxine  on antithyroid medication  \
# 0     41.0  1.0             0                   0                          0
# 1     23.0  1.0             0                   0                          0
# 2     46.0  0.0             0                   0                          0
# 3     70.0  1.0             1                   0                          0
# 4     70.0  1.0             0                   0                          0
# ...    ...  ...           ...                 ...                        ...
# 3767  30.0  1.0             0                   0                          0
# 3768  68.0  1.0             0                   0                          0
# 3769  74.0  1.0             0                   0                          0
# 3770  72.0  0.0             0                   0                          0
# 3771  64.0  1.0             0                   0                          0
#
#       sick  ...   T4U  FTI measured    FTI  TBG measured  referral source  \
# 0        0  ...  1.14             1  109.0             0             SVHC
# 1        0  ...   NaN             0    NaN             0            other
# 2        0  ...  0.91             1  120.0             0            other
# 3        0  ...   NaN             0    NaN             0            other
# 4        0  ...  0.87             1   70.0             0              SVI
# ...    ...  ...   ...           ...    ...           ...              ...
# 3767     0  ...   NaN             0    NaN             0            other
# 3768     0  ...  1.08             1  114.0             0              SVI
# 3769     0  ...  1.07             1  105.0             0            other
# 3770     0  ...  0.94             1   87.0             0              SVI
# 3771     0  ...  1.07             1   92.0             0            other
#
#       binaryClass
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 3767            0
# 3768            0
# 3769            0
# 3770            0
# 3771            0
#
# [3772 rows x 29 columns]

# %%
data["binaryClass"].value_counts()
# Out:
# binaryClass
# 0    3481
# 1     291
# Name: count, dtype: int64

# %%
# dropping unwanted columns
data=data.drop("referral source",axis=1)
data
# Out:
#        age  sex  on thyroxine  query on thyroxine  on antithyroid medication  \
# 0     41.0  1.0             0                   0                          0
# 1     23.0  1.0             0                   0                          0
# 2     46.0  0.0             0                   0                          0
# 3     70.0  1.0             1                   0                          0
# 4     70.0  1.0             0                   0                          0
# ...    ...  ...           ...                 ...                        ...
# 3767  30.0  1.0             0                   0                          0
# 3768  68.0  1.0             0                   0                          0
# 3769  74.0  1.0             0                   0                          0
# 3770  72.0  0.0             0                   0                          0
# 3771  64.0  1.0             0                   0                          0
#
#       sick  ...  T4U measured   T4U  FTI measured    FTI  TBG measured  \
# 0        0  ...             1  1.14             1  109.0             0
# 1        0  ...             0   NaN             0    NaN             0
# 2        0  ...             1  0.91             1  120.0             0
# 3        0  ...             0   NaN             0    NaN             0
# 4        0  ...             1  0.87             1   70.0             0
# ...    ...  ...           ...   ...           ...    ...           ...
# 3767     0  ...             0   NaN             0    NaN             0
# 3768     0  ...             1  1.08             1  114.0             0
# 3769     0  ...             1  1.07             1  105.0             0
# 3770     0  ...             1  0.94             1   87.0             0
# 3771     0  ...             1  1.07             1   92.0             0
#
#       binaryClass
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 3767            0
# 3768            0
# 3769            0
# 3770            0
# 3771            0
#
# [3772 rows x 28 columns]

# %%
data.dtypes
# Out:
# age                          float64
# sex                          float64
# on thyroxine                   int64
# query on thyroxine             int64
# on antithyroid medication      int64
# sick                           int64
# pregnant                       int64
# thyroid surgery                int64
# I131 treatment                 int64
# query hypothyroid              int64
# query hyperthyroid             int64
# lithium                        int64
# goitre                         int64
# tumor                          int64
# hypopituitary                  int64
# psych                          int64
# TSH measured                   int64
# TSH                          float64
# T3 measured                    int64
# T3                           float64
# TT4 measured                   int64
# TT4                          float64
# T4U measured                   int64
# T4U                          float64
# FTI measured                   int64
# FTI                          float64
# TBG measured                   int64
# binaryClass                    int64
# dtype: object

# %%
# filling the missing values using SimpleImputer
imputer=SimpleImputer(strategy='mean')
data["age"]=imputer.fit_transform(data[["age"]])
data["sex"]=imputer.fit_transform(data[["sex"]])
data["TSH"]=imputer.fit_transform(data[["TSH"]])
data["T3"]=imputer.fit_transform(data[["T3"]])
data["TT4"]=imputer.fit_transform(data[["TT4"]])
data["T4U"]=imputer.fit_transform(data[["T4U"]])
data["FTI"]=imputer.fit_transform(data[["FTI"]])

# %%
# checking missing values after imputation
data.isnull().sum()
# Out:
# age                          0
# sex                          0
# on thyroxine                 0
# query on thyroxine           0
# on antithyroid medication    0
# sick                         0
# pregnant                     0
# thyroid surgery              0
# I131 treatment               0
# query hypothyroid            0
# query hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# TSH measured                 0
# TSH                          0
# T3 measured                  0
# T3                           0
# TT4 measured                 0
# TT4                          0
# T4U measured                 0
# T4U                          0
# FTI measured                 0
# FTI                          0
# TBG measured                 0
# binaryClass                  0
# dtype: int64

# %% [markdown]
# #### Splitting features and target variable

# %%
X=data.drop(columns="binaryClass",axis=1)
Y=data["binaryClass"]

# %% [markdown]
# #### Splitting training and testing data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=7)

# %%
# dropping unnecessary or redundant features
X_train=X_train.drop(['FTI', 'FTI measured', 'T4U measured', 'TT4 measured','query on thyroxine','on antithyroid medication','sick', 'pregnant','thyroid surgery','I131 treatment', 'query hypothyroid', 'query hyperthyroid', 'lithium', 'goitre', 'tumor', 'hypopituitary','psych' , 'TSH measured', 'T4U', 'TBG measured'],axis=1)
X_test=X_test.drop(['FTI', 'FTI measured', 'T4U measured', 'TT4 measured','query on thyroxine','on antithyroid medication','sick', 'pregnant','thyroid surgery','I131 treatment', 'query hypothyroid', 'query hyperthyroid', 'lithium', 'goitre', 'tumor', 'hypopituitary','psych' , 'TSH measured', 'T4U', 'TBG measured'],axis=1)

# %% [markdown]
# #### Model creation

# %%
tmodel=LogisticRegression(max_iter=712)
tmodel.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=712)

# %%
Train_data_predict=tmodel.predict(X_train)
Train_data_accuracy=accuracy_score(Y_train,Train_data_predict)
print("Train data accuracy:",Train_data_accuracy)
Test_data_predict=tmodel.predict(X_test)
Test_data_accuracy=accuracy_score(Y_test,Test_data_predict)
print("Test data accuracy:",Test_data_accuracy)
# Out:
# Train data accuracy: 0.957905203844879
# Test data accuracy: 0.9668874172185431

# %% [markdown]
# #### Predictive System

# %%
input=(44,0,0,45,1,1.4,39)
# transforming as array
input_array=np.asarray(input)
# reshaping the array
reshaped_input=input_array.reshape(1,-1)
prediction=tmodel.predict(reshaped_input)
if (prediction[0]==0):
    print("The person does not have HyperThyroid disease.")
else:
    print("The person has HyperThyroid disease.")
# Out:
# The person has HyperThyroid disease.
# C:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #### Saving the trained model

# %%
pickle.dump(tmodel,open('Thyroid_Disease_Prediction.sav','wb'))
# loading the model
loaded_model=pickle.load(open('Thyroid_Disease_Prediction.sav','rb'))
for column in X_train.columns:
    print(column)
# Out:
# age
# sex
# on thyroxine
# TSH
# T3 measured
# T3
# TT4
